# %%
import numpy as np
import pandas as pd
import os
import folium
from folium import plugins
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
entries = os.listdir('Desktop/Asheville/')
#listings = pd.read_csv("Desktop/Asheville/listings.csv", index_col="id", low_memory=False)
listings = pd.read_csv("Desktop/Asheville/listings.csv", header=0,encoding = 'unicode_escape')

# %%
listings.id.nunique()
# Out:
# 2053

# %%
listings_details = pd.read_csv("Desktop/Asheville/listings_details.csv", index_col="id", low_memory=False)

# %%
target_columns = ["property_type", "accommodates", "first_review", "review_scores_value",
                  "review_scores_cleanliness", "review_scores_location",
                  "review_scores_accuracy", "amenities", "review_scores_communication",
                  "review_scores_checkin", "review_scores_rating", "bed_type", "maximum_nights",
                  "listing_url", "host_is_superhost", "host_about", "host_response_time",
                  "host_response_rate", "street", "weekly_price", "monthly_price",'bedrooms', 'bathrooms', 'beds',
                  "market", 'availability_30', 'availability_60', 'availability_90','neighbourhood_cleansed',]
listings = pd.merge(listings, listings_details[target_columns], on='id', how='left')
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2053 entries, 0 to 2052
# Data columns (total 45 columns):
# id                                2053 non-null int64
# name                              2053 non-null object
# host_id                           2053 non-null int64
# host_name                         2053 non-null object
# neighbourhood_group               0 non-null float64
# neighbourhood                     2053 non-null int64
# latitude                          2053 non-null float64
# longitude                         2053 non-null float64
# room_type                         2053 non-null object
# price                             2053 non-null int64
# minimum_nights                    2053 non-null int64
# number_of_reviews                 2053 non-null int64
# last_review                       1854 non-null object
# reviews_per_month                 1854 non-null float64
# calculated_host_listings_count    2053 non-null int64
# availability_365                  2053 non-null int64
# property_type                     2053 non-null object
# accommodates                      2053 non-null int64
# first_review                      1854 non-null object
# review_scores_value               1849 non-null float64
# review_scores_cleanliness         1849 non-null float64
# review_scores_location            1849 non-null float64
# review_scores_accuracy            1849 non-null float64
# amenities                         2053 non-null object
# review_scores_communication       1849 non-null float64
# review_scores_checkin             1849 non-null float64
# review_scores_rating              1850 non-null float64
# bed_type                          2053 non-null object
# maximum_nights                    2053 non-null int64
# listing_url                       2053 non-null object
# host_is_superhost                 2053 non-null object
# host_about                        1490 non-null object
# host_response_time                1846 non-null object
# host_response_rate                1846 non-null object
# street                            2053 non-null object
# weekly_price                      271 non-null object
# monthly_price                     237 non-null object
# bedrooms                          2053 non-null int64
# bathrooms                         2053 non-null float64
# beds                              2053 non-null int64
# market                            2045 non-null object
# availability_30                   2053 non-null int64
# availability_60                   2053 non-null int64
# availability_90                   2053 non-null int64
# neighbourhood_cleansed            2053 non-null int64
# dtypes: float64(12), int64(16), object(17)
# memory usage: 737.8+ KB

# %%
listings.groupby(by='neighbourhood').count()[['id']].sort_values(by='id', ascending=False).head(10)
# Out:
#                 id
# neighbourhood
# 28806          603
# 28801          491
# 28803          300
# 28804          244
# 28805          234
# 28704          111
# 28715           35
# 28732           35

# %%
import matplotlib.pyplot as plt
feq=listings['neighbourhood_cleansed'].value_counts().sort_values(ascending=True)
feq.plot.barh(figsize=(10, 8), color='b', width=1)
plt.title("Number of listings by neighbourhood", fontsize=20)
plt.xlabel('Number of listings', fontsize=12)
plt.ylabel('zipcode', fontsize=12)
plt.show()

# %%
listings[['id','neighbourhood_cleansed','latitude','longitude']].head()
# Out:
#        id  neighbourhood_cleansed  latitude  longitude
# 0   38585                   28804  35.65146  -82.62792
# 1   80905                   28801  35.59701  -82.55237
# 2  108061                   28801  35.60670  -82.55563
# 3  155305                   28806  35.57972  -82.59617
# 4  156805                   28806  35.57755  -82.59697

# %%
m = folium.Map([35.59055, -82.55447], zoom_start=11)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lats2018 = listings['latitude'].tolist()
lons2018 = listings['longitude'].tolist()
locations = list(zip(lats2018, lons2018))
len(locations)
locations[7]
# Out:
# (35.59055, -82.55447)

# %%
from folium.plugins import HeatMap
from folium.plugins import MarkerCluster
import json


map_hooray = folium.Map(location=[35.59055, -82.55447],
                    zoom_start = 13) 

locations = listings[['latitude', 'longitude']].as_matrix()
icons = [folium.Icon(icon="home", prefix="fa") for _ in range(len(locations))]

cluster = MarkerCluster(locations=locations, icons=icons)
map_hooray.add_child(cluster)
map_hooray

# Display the map
map_hooray
# Out:
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if __name__ == '__main__':
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Cleaning the data
import re
calendarDF = pd.read_csv("Desktop/Asheville/calendar.csv")
#print('We have', calendar.date.nunique(),
      #'days and', calendar.listing_id.nunique(),
      #'unique listings in the calendar data.')

#replacing NaN values with 0
calendarDF.fillna(0, inplace=True)
calendarDF = calendarDF[calendarDF.price != 0]

#Extracting prices from the table
price = calendarDF['price']
prices=[]

for p in price:
    p = re.sub('[^0-9.]+','', p)
    prices.append(float(p))
    
#replace the price column with the new column
calendarDF['price']=prices

calendarDF = calendarDF[calendarDF.price >= 0]

#separating date column into day month and year
calendarDF['Year'],calendarDF['Month'],calendarDF['Day']=calendarDF['date'].str.split('-',2).str


calendarDF = calendarDF.drop(columns=['adjusted_price'])
calendarDF.head()
# Out:
#    listing_id        date available  price  minimum_nights  maximum_nights  \
# 0    21733951  2019-02-17         f   69.0               1              90
# 1    21733951  2019-02-18         f   69.0               1              90
# 2    21733951  2019-02-19         f   69.0               1              90
# 3    21733951  2019-02-20         f   69.0               1              90
# 4    21733951  2019-02-21         f   69.0               1              90
#
#    Year Month Day
# 0  2019    02  17
# 1  2019    02  18
# 2  2019    02  19
# 3  2019    02  20
# 4  2019    02  21

# %%
yearDF=calendarDF.groupby(['Year','Month']).price.mean()
yearDF=yearDF.reset_index()
yearDF=yearDF.rename(columns={'price':'average_Price'})
yearDF['year-Month']=yearDF['Year'].map(str) + "-" + yearDF['Month'].map(str)
yearDF.to_csv('year_month_data.csv')
yearDF.head()
# Out:
#    Year Month  average_Price year-Month
# 0  2019    02     137.004627    2019-02
# 1  2019    03     148.866364    2019-03
# 2  2019    04     154.497500    2019-04
# 3  2019    05     156.997203    2019-05
# 4  2019    06     160.785176    2019-06

# %%
# visualizing the trend of year/Month and average prices of the listing


import matplotlib
matplotlib.style.use('ggplot')

objects = yearDF['year-Month']
y_pos = yearDF['average_Price']

yearDF.plot(kind='bar', 
           x='year-Month',
           y='average_Price',
           color = '#66c2ff', 
           figsize =(15,8), 
           title = 'Asheville Airbnb prices trend over months', 
           legend = False)
plt.ylabel('Average Price')
# Out:
# Text(0, 0.5, 'Average Price')

# %%
#getting day name from date data and holidays

from datetime import date
import datetime
import calendar
import holidays

calendarDF.fillna(0, inplace=True)
us_holidays = holidays.US()

calendarDF['day_Name']='default'
calendarDF['holiday']='False'
calendarDF['us_holidays_name']='working'
for index,row in calendarDF.iterrows():
    sdate = datetime.date(int(row['Year']),int(row['Month']),int(row['Day']))
    vall=date(int(row['Year']),int(row['Month']),int(row['Day'])) in us_holidays
    calendarDF.set_value(index,'day_Name',calendar.day_name[sdate.weekday()])
    calendarDF.set_value(index,'holiday',vall)
    calendarDF.set_value(index,'us_holidays_name',us_holidays.get(sdate))
calendarDF.to_csv('holidays_data.csv')
calendarDF.head()
# Out:
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#    listing_id        date available  price  minimum_nights  maximum_nights  \
# 0    21733951  2019-02-17         f   69.0               1              90
# 1    21733951  2019-02-18         f   69.0               1              90
# 2    21733951  2019-02-19         f   69.0               1              90
# 3    21733951  2019-02-20         f   69.0               1              90
# 4    21733951  2019-02-21         f   69.0               1              90
#
#    Year Month Day   day_Name holiday       us_holidays_name
# 0  2019    02  17     Sunday   False                   None
# 1  2019    02  18     Monday    True  Washington's Birthday
# 2  2019    02  19    Tuesday   False                   None
# 3  2019    02  20  Wednesday   False                   None
# 4  2019    02  21   Thursday   False                   None

# %%
#calculating Average price for each day

dayDF=calendarDF.groupby('day_Name').price.mean()
dayDF=dayDF.reset_index()
dayDF['day_num']=0

for index,row in dayDF.iterrows():
    if row['day_Name']=='Monday':
        dayDF.set_value(index,'day_num',1)
    if row['day_Name']=='Tuesday':
        dayDF.set_value(index,'day_num',2)
    if row['day_Name']=='Wednesday':
        dayDF.set_value(index,'day_num',3)
    if row['day_Name']=='Thursday':
        dayDF.set_value(index,'day_num',4)
    if row['day_Name']=='Friday':
        dayDF.set_value(index,'day_num',5)
    if row['day_Name']=='Saturday':
        dayDF.set_value(index,'day_num',6)
    if row['day_Name']=='Sunday':
        dayDF.set_value(index,'day_num',7)
dayDF=dayDF.sort_values('day_num',ascending=[1])
dayDF=dayDF.rename(columns={'price':'Average_Price'})
dayDF
# Out:
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\AKINLOLU\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
#     day_Name  Average_Price  day_num
# 1     Monday     157.400708        1
# 5    Tuesday     157.246019        2
# 6  Wednesday     157.355062        3
# 4   Thursday     158.493153        4
# 0     Friday     175.368139        5
# 2   Saturday     175.733664        6
# 3     Sunday     158.485502        7

# %%
holidayDF=calendarDF.groupby('us_holidays_name').listing_id.count()
holidayDF=holidayDF.reset_index()
holidayDF=holidayDF.sort_values('listing_id',ascending=[0])
holidayDF
# Out:
#               us_holidays_name  listing_id
# 0                Christmas Day        2053
# 1                 Columbus Day        2053
# 2             Independence Day        2053
# 3                    Labor Day        2053
# 4  Martin Luther King, Jr. Day        2053
# 5                 Memorial Day        2053
# 6               New Year's Day        2053
# 7                 Thanksgiving        2053
# 8                 Veterans Day        2053
# 9        Washington's Birthday        2053

# %%
# visualizing the same
plt.figure(figsize=(19,8))
ax = sns.barplot("us_holidays_name", y="listing_id", data=holidayDF,palette="Blues_d")
ax.set(xlabel='US Holidays Name', ylabel='Total Number of Listings')
# Out:
# [Text(0, 0.5, 'Total Number of Listings'), Text(0.5, 0, 'US Holidays Name')]

# %%
holidayPriceDF=calendarDF.groupby('us_holidays_name').price.mean()
holidayPriceDF=holidayPriceDF.reset_index()
holidayPriceDF=holidayPriceDF.sort_values('price',ascending=[0])

holidayPriceDF.head(10)
# Out:
#               us_holidays_name       price
# 0                Christmas Day  168.630297
# 7                 Thanksgiving  168.454457
# 1                 Columbus Day  166.369216
# 3                    Labor Day  166.231856
# 6               New Year's Day  166.100341
# 2             Independence Day  165.005358
# 8                 Veterans Day  162.625426
# 4  Martin Luther King, Jr. Day  160.014126
# 5                 Memorial Day  157.006332
# 9        Washington's Birthday  133.385290

# %%
# visualizing the same
plt.figure(figsize=(19,8))
ax = sns.barplot("us_holidays_name", y="price", data=holidayPriceDF,palette="Blues_d")
ax.set(xlabel='US Holidays Name', ylabel='Average Price')
# Out:
# [Text(0, 0.5, 'Average Price'), Text(0.5, 0, 'US Holidays Name')]

# %%
merger=pd.merge(holidayDF,holidayPriceDF,on='us_holidays_name')
merger=merger.rename(columns={'listing_id':'number_Of_Listings'})
merger=merger.rename(columns={'price':'average_Price'})
merger
# Out:
#               us_holidays_name  number_Of_Listings  average_Price
# 0                Christmas Day                2053     168.630297
# 1                 Columbus Day                2053     166.369216
# 2             Independence Day                2053     165.005358
# 3                    Labor Day                2053     166.231856
# 4  Martin Luther King, Jr. Day                2053     160.014126
# 5                 Memorial Day                2053     157.006332
# 6               New Year's Day                2053     166.100341
# 7                 Thanksgiving                2053     168.454457
# 8                 Veterans Day                2053     162.625426
# 9        Washington's Birthday                2053     133.385290

# %%
checkHolidaysDF=calendarDF[(calendarDF['Year'] == '2019') & ((calendarDF['Month'] == '09') |(calendarDF['Month'] == '10'))]
checkHolidaysDF=checkHolidaysDF.groupby(['Year','Month','holiday']).price.mean()
checkHolidaysDF=checkHolidaysDF.reset_index()
checkHolidaysDF.head()
# Out:
#    Year Month  holiday       price
# 0  2019    09    False  168.302182
# 1  2019    09     True  166.231856
# 2  2019    10    False  171.798847
# 3  2019    10     True  166.369216

# %%
#analyzing longweekednd holiday days

columbusDF=calendarDF[(calendarDF['Year'] == '2019') & (calendarDF['Month'] == '10' ) & ((calendarDF['Day'] == '08') | (calendarDF['Day'] == '09') | (calendarDF['Day'] == '10'))]
columbusDF.groupby('Month').price.mean()
# Out:
# Month
# 10    166.606105
# Name: price, dtype: float64

# %%
#analyzing rest of the days

NocolumbusDF=calendarDF[(calendarDF['Year'] == '2019') & (calendarDF['Month'] == '10' ) & ((calendarDF['Day'] != '08') | (calendarDF['Day'] != '09') | (calendarDF['Day'] != '10'))]
NocolumbusDF.groupby('Month').price.mean()
# Out:
# Month
# 10    171.623698
# Name: price, dtype: float64

# %%
# analyzing data from date 5th of October to date 13th of October which includes both long weekend and normal workdays

octDF=calendarDF[(calendarDF['Year'] == '2019') & (calendarDF['Month'] == '10' )& ((calendarDF['Day'] == '05' )| (calendarDF['Day'] == '06' )| (calendarDF['Day'] == '07' )| (calendarDF['Day'] == '08' )| (calendarDF['Day'] == '09' )| (calendarDF['Day'] == '10' )| (calendarDF['Day'] == '10' )| (calendarDF['Day'] == '11' )| (calendarDF['Day'] == '12' )| (calendarDF['Day'] == '13' ))]
octDF=octDF.groupby('Day').price.mean()
octDF=octDF.reset_index()
octDF=octDF.sort_values('Day',ascending=[1])
octDF=octDF.rename(columns={'price':'Average_Price'})
octDF.head(10)
# Out:
#   Day  Average_Price
# 0  05     185.852411
# 1  06     166.570872
# 2  07     166.020458
# 3  08     166.220653
# 4  09     166.128105
# 5  10     167.469557
# 6  11     186.197272
# 7  12     186.350706
# 8  13     167.109109

# %%
x=octDF['Day'].tolist()
y=octDF['Average_Price'].tolist()

plt.plot(x,y, 'ro-')
plt.ylabel('Average Price')
plt.xlabel('Days')
plt.show()
